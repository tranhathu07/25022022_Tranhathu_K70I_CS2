# %%
print('Hello World')
# Out:
# Hello World

# %%
#W2A2
ten = input()
print(f'Hello {ten}')
# Out:
#  th
# Hello th

# %%
#W2A3
a = int(input('Nhập a: '))
b = int(input('Nhập b:  '))
print(f'Tong = {a+b}, Hieu = {a-b}, Tich = {a*b}, Phan nguyen = {a//b}, Phan du = {a%b}, kq chia thực = {round(a/b, 2)}')
# Out:
# Nhập a:  4
# Nhập b:   2
# Tong = 6, Hieu = 2, Tich = 8, Phan nguyen = 2, Phan du = 0, kq chia thực = 2.0

# %%
#W2A4
a1,b1,c1,a2,b2,a3 = map(float, input('Nhập 6 đầu điểm: ').split())
print(f'Điểm trung bình môn học của 6 môn học: {round((((a1+b1+c1) + (a2+b2)*2 + a3 *3)/10),2)}')
# Out:
# Nhập 6 đầu điểm:  1 2 3 4 5 6
# Điểm trung bình môn học của 6 môn học: 4.2

# %%
#W2A5
a,b = map(int, input('Nhập hai số a và b: ').split())
print('Kết quả của a mũ b là', a**b)
# Out:
# Nhập hai số a và b:  2 3
# Kết quả của a mũ b là 8

# %%
#W2A6
albet = input('Nhập chữ cái in thường:' )
print('Mã Unicode của chữ đó:', ord(albet))
print('Chữ cái in hoa của chữ đó:', chr(ord(albet)-32))
# Out:
# Nhập chữ cái in thường: r
# Mã Unicode của chữ đó: 114
# Chữ cái in hoa của chữ đó: R

# %%
#W2A7
A = ((13**2)*3)+5
B = 13**2*3 +5
print(A)
print(B)
# Out:
# 512
# 512

# %%
#W2A8
celcius = float(input('Độ C: '))
def celcius_transfer(celcius):
    f = 9/5*celcius + 32
    return f
print(round(celcius_transfer(celcius),3))
# Out:
# Độ C:  12.3
# 54.14

# %%
#W2Aa9
x = float(input('Nhập giá tiền của đồng hồ: '))
print(f'Giá tiền Sơn Tùng phải trả là:{round((x+10)*1.4,3)}')
# Out:
# Nhập giá tiền của đồng hồ:  17.8
# Giá tiền Sơn Tùng phải trả là:38.92

# %%
#W2A10
ng1,ng2,ng3 = input('Nhập tên của 3 người ').split()
print(f'Hi {ng3}, {ng2} and {ng1}.')
# Out:
# Nhập tên của 3 người  a b c
# Hi c, b and a.

# %%
#W2A11
h, m = map(int,input('Nhập lần lượt số giờ và số phút: ').split())
print(f'Số giây là:{h*3600 + m*60}')
# Out:
# Nhập lần lượt số giờ và số phút:  1 20
# Số giây là:4800

# %%
#W2A12
n = int(input('Nhập đô dài cạnh rubik: '))
print('Số miếng riêng lẻ cần dùng:',n**2*6)
# Out:
# Nhập đô dài cạnh rubik:  2
# Số miếng riêng lẻ cần dùng: 24

# %%
#W2A13
a,b = map(int, input('Nhập 2 số nguyên dương a và b: ').split())
tich = str(a*b)
print(tich[-1])
# Out:
# Nhập 2 số nguyên dương a và b:  12 13
# 6

# %%
#W2A14
a,b = map(int,input('Nhập hai số a và b: ').split())
a = a+b
b = a-b
a = a-b
print(a,b)
# Out:
# Nhập hai số a và b:  2 4
# 4 2

# %%
#W2A15
n = int(input())
print(6*n*(n-1)+1)
# Out:
#  3
# 37

# %%
#W2A16
print('Spring\nSummer\nAutumn\nWinter')
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
'''
for i in range(1,6,2):
    print('*'*i,end='\n')
'''
print('*')
print('***')
print('*****')
# Out:
# *
# ***
# *****

# %%
#W2A18
print('### # #   ###  ###')
print(' #  #  #   #   #')
print(' #  #   #  #   #')
print(' #  #  #   #   #')
print(' #  # #    #   #')
# Out:
# ### # #   ###  ###
#  #  #  #   #   #
#  #  #   #  #   #
#  #  #  #   #   #
#  #  # #    #   #

# %%
#W2A20
print('Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday')
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A19
print('January\nFebruary\nMarch\nApril\nMay\nJune\nJuky\nAugust\nSeptember\nOctober\nNovember\nDecember')
# Out:
# January
# February
# March
# April
# May
# June
# Juky
# August
# September
# October
# November
# December

# %%
#W2A21
for i in range(10):
    print('Hello, world')
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
