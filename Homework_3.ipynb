# %%
#W3A2
a,b = map(int, input('Nhập 2 số nguyên a và b: ').split())
a = a^b
b= a^b
a = a^b
print(f'Kết quả sau hoán đổi 2 số là: a= {a} và b = {b}')
# Out:
# Nhập 2 số nguyên a và b:  1 2
# Kết quả sau hoán đổi 2 số là: a= 2 và b = 1

# %%
#W3A3
n = int(input())
if n & n-1 == 0:
    print(f'Số {n} là lũy thừa của 2')
else:
    print(f'Số {n} không là lũy thừa của 2')
# Out:
#  5
# Số 5 không là lũy thừa của 2

# %%
#W3A4
m,n = map(int,input('Nhập số chia m và số bị chia n: ').split())
print(int(n/m))
# Out:
# Nhập số chia m và số bị chia n:  2 5
# 2

# %%
import math
m,n = map(int,input('Nhập số chia m và số bị chia n: ').split())
print(int((n+m-1)/m))
# Out:
# Nhập số chia m và số bị chia n:  5 17
# 4

# %%
#W3A7
n = int(input('Nhập số nguyên dương x: '))
if n %2==0:
    print('Even')
else:
    print('Odd')
# Out:
# Nhập số nguyên dương x:  5
# Odd

# %%
#W2A7
a,b = map(int,input('Nhập 2 số nguyên a và b: ').split())
if a<0 and b <0:
    print('Yes')
else:
    print('No')
# Out:
# Nhập 2 số nguyên a và b:  -5 -6
# Yes

# %%
a,b = input('Nhập 2 chuỗi a và b: ').split()
if len(a) > len(b):
    print('True')
else:
    print('False')
# Out:
# Nhập 2 chuỗi a và b:  hsdsidhdiodsp ãaxsaxs
# True

# %%
#W3A10
a,b,c,d = map(int,input('Nhập 4 số nguyên: ').split())
print(max(a,b,c,d))
# Out:
# Nhập 4 số nguyên:  83 42432 4234 343
# 42432

# %%
a,b,c = map(float,input('Nhập độ dài 3 cạnh: ').split())
if abs(a-b)<c<a+b and abs(a-c)<b<a+c and abs(b-c)<a<b+c:
    if a ==b or b ==c or a ==c:
        if a ==b == c:
            print('Tam giác đều')
        else:
            print('Tam giác cân')
    else:
        print('Tam giác thường')
else:
    print('Không phải tam giác')
# Out:
# Nhập độ dài 3 cạnh:  1 1 2
# Không phải tam giác

# %%
#W3A12
n = int(input('Nhập số năm:'))
if n %4 == 0 and n%100 != 0 or n %400 == 0:
    print('Yes')
else:
    print('No')
# Out:
# Nhập số năm: 2025
# No

# %%
#W3A14
a,b = map(float,input('Nhập vào hai số thực a và b của phương trình ax + b = 0: ').split())
print(round(-b/a,2))
# Out:
# Nhập vào hai số thực a và b của phương trình ax + b = 0:  6 5
# -0.83

# %%
#W3A15
n = float(input('Nhập điểm trung bình: '))
if n >= 8:
    print('Giỏi')
elif n>=6.5:
    print('Khá')
elif n>= 5:
    print('Trung bình')
else:
    print('Yếu')
# Out:
# Nhập điểm trung bình:  5
# Trung bình

# %%
a = float(input())

#làm tròn xuống
if a >=0:
    x = int(a)
else:
    if a != x:
        x = int(a)-1
    else: a = int(x)
# Làm tròn lên
if a>=0:
    if d!= int(a):
        d = int(a)+1
    else:
        d = int(a)
else:
    d = int(a)

#Làm tròn đến số nguyên gần nhất
if a >=0:
    if a - int(a) < 0.5:
        f = int(a)
    else:
        f = int(a) +1
else:
    if a - int(a) < 0.5:
        f = int(a) +1
    else:
        f = int(a)
print(x,d,f)
# Out:
#  4.6
# 4 5 5

# %%
#W3A17
a,b,c,d = map(float,input('Nhập 4 số : ').split())
q = b/a
if b*q == c and c*q == d:
    print('4 số này có thể theo thứ tự tạo thành 1 cấp số nhân')
else:
    print('4 số này không thể theo thứ tự tạo thành 1 cấp số nhân')
# Out:
# Nhập 4 số :  1 2 3 4
# 4 số này không thể theo thứ tự tạo thành 1 cấp số nhân
