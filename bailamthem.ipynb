# %%
'''
try:
    date,month,year = map(int,input('Nhập ngày tháng năm theo định dạng date/month/year:' ).split('/'))
    if 1900<=year:
        if 0<month<=12:
            if month in [1,3,5,7,8,10,12]:
                if 0<date<32:
                    print('Valid')
                else:
                    print('Invalid')
            elif month in [4,6,9,11]:
                if 0<date<31:
                    print('Valid')
                else:
                    print('Invalid')
            elif month == 2:
                cuoi = year%100
                nhuan = (cuoi %4 ==0)
                if nhuan and 0<date<30:
                    print('Valid')
                elif not nhuan and 0<date<29:
                    print('Valid')
                else:
                    print('Invalid')
                    
        else:
            print('Invalid')
    else:
        print('Invalid')   
except:
    print('Invalid')
'''
#Cách matchcase
try:
    date,month,year = map(int,input('Nhập ngày tháng năm theo định dạng date/month/year:' ).split('/'))
    Max = 0
    match month:
        case (4,6,9,11): Max = 30
        case (1,3,5,7,8,10,12): Max = 31
        case 2: 
            cuoi = year%100
            nhuan = (cuoi %4 ==0)
            if nhuan: Max = 29
            else : Max = 28
    if 0 <= date<= Max and year >=1900:
        print('Valid')
    else:
        print('Invalid')
        
except:
    print('Invalid')
# Out:
# Nhập ngày tháng năm theo định dạng date/month/year: 29/02/2024
# Valid
